# %%
with open("Sample1.txt","r") as document:
    file = document.readline()
print(file)
# Out:
# Utilitatis causa amicitia est quaesita.

# %%
import pandas as pd
files =pd.read_excel('Financial Sample.xlsx')
print(files.head(5))
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government   Canada  Carretera           NaN      1618.5
# 1  Government  Germany  Carretera           NaN      1321.0
# 2   Midmarket   France  Carretera           NaN      2178.0
# 3   Midmarket  Germany  Carretera           NaN       888.0
# 4   Midmarket   Mexico  Carretera           NaN      2470.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                    3          20      32370.0        0.0  32370.0  16185.0
# 1                    3          20      26420.0        0.0  26420.0  13210.0
# 2                    3          15      32670.0        0.0  32670.0  21780.0
# 3                    3          15      13320.0        0.0  13320.0   8880.0
# 4                    3          15      37050.0        0.0  37050.0  24700.0
#
#     Profit       Date  Month Number Month Name  Year
# 0  16185.0 2014-01-01             1    January  2014
# ...

# %%
print(set(files['Discount Band']))
# Out:
# {'Medium', nan, 'Low', 'High'}

# %%
files.columns
# Out:
# Index(['Segment', 'Country', 'Product', 'Discount Band', 'Units Sold',
#        'Manufacturing Price', 'Sale Price', 'Gross Sales', 'Discounts',
#        ' Sales', 'COGS', 'Profit', 'Date', 'Month Number', 'Month Name',
#        'Year'],
#       dtype='object')

# %%
files.index
# Out:
# RangeIndex(start=0, stop=700, step=1)

# %%
print(set(files['Country']))
# Out:
# {'USA', 'Canada', 'Germany', 'France', 'Mexico'}

# %%
files['Country'] = files["Country"].replace('United States of America','USA')

# %%
print(set(files[['Country', 'Sale Price']]))
# Out:
# {'Country', 'Sale Price'}

# %%
# to find which products and countries have a high discount band
print(files
    [
        (files['Discount Band'] == 'High') &
        (files['Country'] == 'USA')
    ]
[['Segment','Product']])
# Out:
#               Segment    Product
# 455  Channel Partners  Carretera
# 456        Government    Montana
# 457  Channel Partners      Paseo
# 458        Enterprise  Carretera
# 460        Government    Montana
# 461        Enterprise    Montana
# 469         Midmarket       Velo
# 471        Enterprise       Velo
# 472    Small Business       Velo
# 479        Government        VTT
# 481    Small Business        VTT
# 485        Enterprise   Amarilla
# 487    Small Business   Amarilla
# 499        Government        VTT
# 501         Midmarket   Amarilla
# 535        Government      Paseo
# 540         Midmarket    Montana
# 546    Small Business      Paseo
# 558        Government       Velo
# 563        Government        VTT
# 564        Enterprise        VTT
# 566        Government   Amarilla
# 569         Midmarket   Amarilla
# 576         Midmarket  Carretera
# 577         Midmarket        VTT
# 581        Government    Montana
# 582        Government    Montana
# ...

# %%
print(
    max(files['Profit'])[files['Product']]

)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[97], line 2
#       1 print(
# ----> 2     max(files['Profit'])[files['Product']]
#       3
#       4 )
#
# TypeError: 'float' object is not subscriptable
